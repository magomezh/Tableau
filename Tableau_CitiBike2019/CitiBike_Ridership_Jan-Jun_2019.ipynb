# %%
import pandas as pd
from glob import glob
import datetime 
import numpy as np

# %%
riders_data = sorted(glob("ridership/CitibikeData2019_******.csv"))
riders_data
# Out:
# ['ridership/CitibikeData2019_AprJune.csv',
#  'ridership/CitibikeData2019_JanMarch.csv']

# %%
riders_data_2019 = pd.concat((pd.read_csv(file).assign(filename = file)
          for file in riders_data), ignore_index = True)
riders_data_2019
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#      24-Hour Passes Purchased (midnight to 11:59 pm)  \
# 0                                               1466
# 1                                               1483
# 2                                               3013
# 3                                               2633
# 4                                                812
# ..                                               ...
# 156                                             1583
# 157                                             1966
# 158                                             2573
# 159                                             9151
# 160                                             1916
#
# ...

# %%
riders_data_2019 = riders_data_2019.drop(columns=['Column 1', 'filename'])
riders_data_2019.head()
# Out:
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# 0                                             1466
# 1                                             1483
# 2                                             3013
# 3                                             2633
# 4                                              812
#
#    3-Day Passes Purchased (midnight to 11:59 pm)    Date  \
# 0                                             76  4/1/19
# 1                                             73  4/2/19
# 2                                             79  4/3/19
# 3                                             87  4/4/19
# 4                                             46  4/5/19
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        75072
# 1                                        83399
# 2                                       108780
# 3                                       104268
# 4                                        46930
#
# ...

# %%
riders_data_2019.rename(columns={'24-Hour Passes Purchased (midnight to 11:59 pm)': '24-Hour Passes', '3-Day Passes Purchased (midnight to 11:59 pm)': '3-Day Passes', 'Miles traveled today (midnight to 11:59 pm)': 'Miles Traveled Today'}, inplace=True)

# %%
riders_data_2019.head()
# Out:
#    24-Hour Passes  3-Day Passes    Date  Miles Traveled Today  \
# 0            1466            76  4/1/19                 75072
# 1            1483            73  4/2/19                 83399
# 2            3013            79  4/3/19                108780
# 3            2633            87  4/4/19                104268
# 4             812            46  4/5/19                 46930
#
#    Total Annual Members  Trips over the past 24-hours (midnight to 11:59pm)
# 0                303223                                              51399
# 1                303386                                              57903
# 2                303552                                              67924
# 3                303699                                              66403
# 4                303766                                              34470

# %%
riders_data_2019.rename(columns={ 'Total Annual Members (All Time)': 'Total Annual Members', 'Trips over the past 24-hours (midnight to 11:59pm)': 'Trips over the past 24-hours', }, inplace=True)

# %%
riders_data_2019.head()
# Out:
#    24-Hour Passes  3-Day Passes    Date  Miles Traveled Today  \
# 0            1466            76  4/1/19                 75072
# 1            1483            73  4/2/19                 83399
# 2            3013            79  4/3/19                108780
# 3            2633            87  4/4/19                104268
# 4             812            46  4/5/19                 46930
#
#    Total Annual Members  Trips over the past 24-hours
# 0                303223                         51399
# 1                303386                         57903
# 2                303552                         67924
# 3                303699                         66403
# 4                303766                         34470

# %%
riders_data_2019.to_csv('ridership/CitiBike_Ridership_2019.csv', sep = ',', header = True)
